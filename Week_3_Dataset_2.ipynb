# %% [markdown]
# <a href="https://colab.research.google.com/github/purva1803/Dataset_Cleaning/blob/main/Week_3_Dataset_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv("/content/chipotle.tsv",sep='\t')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
data.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# # To identify missing values from dataset

# %%
data.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data.choice_description.fillna('Unknown', inplace=True)

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown     $2.39
# ...

# %%
data.isna().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# dtype: int64

# %% [markdown]
# # To find duplicates from dataset

# %%
duplicates = data[data.duplicated()]

# %%
print("Duplicated entries:")
print(duplicates)
# Out:
# Duplicated entries:
#       order_id  quantity                            item_name  \
# 238        103         1                        Steak Burrito
# 248        108         1                          Canned Soda
# 297        129         1                        Steak Burrito
# 381        165         1                    Canned Soft Drink
# 484        205         1                         Chicken Bowl
# 567        233         1                    Canned Soft Drink
# 617        254         1                                Chips
# 684        282         1                    Canned Soft Drink
# 773        319         1                         Chicken Bowl
# 908        376         1                        Steak Burrito
# 924        381         1                   Chicken Soft Tacos
# 1003       412         1                        Bottled Water
# 1117       462         1                      Chicken Burrito
# 1203       491         1                      Chicken Burrito
# ...

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Quantity of each item

# %%
item_quantity = data.groupby('item_name')['quantity'].sum()
print("Quantity of each item:")
print(item_quantity)
# Out:
# Quantity of each item:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             65
# Barbacoa Burrito                          90
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                        9
# Barbacoa Soft Tacos                       25
# Bottled Water                            204
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              124
# Canned Soft Drink                        340
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             752
# Chicken Burrito                          584
# Chicken Crispy Tacos                      50
# ...

# %%
data.quantity.max()
# Out:
# 15

# %%
data.quantity.min()
# Out:
# 1

# %% [markdown]
# # Total number of items ordered

# %%
total_items_ordered = data['quantity'].sum()
print("Total items ordered:", total_items_ordered)
# Out:
# Total items ordered: 4913

# %%
data.item_price.max()
# Out:
# '$9.39 '

# %% [markdown]
# # Revenue for the period in the dataset

# %%
data = data.copy()
data['revenue'] = data['quantity'] * data['item_price']
total_revenue = data['revenue'].sum()
print("nTotal revenue for the period:", total_revenue)
# Out:
# nTotal revenue for the period: $2.39 $3.39 $3.39 $2.39 $16.98 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $17.98 $1.69 $17
# ...

# %% [markdown]
# # Number of orders made in the period

# %%
total_orders = data['order_id'].nunique()
print("Total orders:", total_orders)
# Out:
# Total orders: 1834

# %%
data.item_name.value_counts()
# Out:
# Chicken Bowl                             717
# Chicken Burrito                          546
# Chips and Guacamole                      474
# Steak Burrito                            365
# Canned Soft Drink                        290
# Steak Bowl                               210
# Chips                                    208
# Bottled Water                            155
# Chicken Soft Tacos                       111
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              102
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          90
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             65
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %% [markdown]
# # Average revenue amount per order

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                               Unknown     $2.39
# ...

# %% [markdown]
# # Number of unique items sold

# %%
data.groupby('order_id')['item_name'].nunique().reset_index()
# Out:
#       order_id  item_name
# 0            1          4
# 1            2          1
# 2            3          2
# 3            4          2
# 4            5          2
# ...        ...        ...
# 1829      1830          2
# 1830      1831          3
# 1831      1832          2
# 1832      1833          1
# 1833      1834          1
#
# [1834 rows x 2 columns]

# %%
unique_items_sold = data['item_name'].nunique()
print("Number of unique items sold:", unique_items_sold)
# Out:
# Number of unique items sold: 50

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                               Unknown        2.39
# ...

# %%
data.revenue = data.revenue.str.lower().str.replace('$',' ')
# Out:
# <ipython-input-40-27d2ab095ba1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.revenue = data.revenue.str.lower().str.replace('$',' ')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                               Unknown        2.39
# ...
